# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from datetime import datetime
from citipy import citipy

# %%
# Create set of 2000 lats and lngs
lats = np.random.uniform(-90,90,2000)
lngs = np.random.uniform(-180,180,2000)
coordinates = list(zip(lats, lngs))

# %%
# Create list for cities and iterate through coordinates
cities = []
for coord in coordinates:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    # Append city name into cities list
    if city not in cities:
        cities.append(city)
cities
# Out:
# ['amderma',
#  'lorengau',
#  'eldikan',
#  'port alfred',
#  'east london',
#  'shenjiamen',
#  'nikolskoye',
#  'georgetown',
#  'illoqqortoormiut',
#  'iqaluit',
#  'hovd',
#  'qaanaaq',
#  'kilcullen',
#  'lebu',
#  'albany',
#  'goderich',
#  'chuy',
#  'bargal',
#  'attawapiskat',
#  'cape town',
#  'meyungs',
#  'nampula',
#  'port elizabeth',
#  'vardo',
#  'polunochnoye',
#  'nanortalik',
#  'rundu',
#  'mount gambier',
#  'cherskiy',
#  'victoria',
#  'mataura',
#  'bluff',
#  'prince albert',
#  'butaritari',
#  'taolanaro',
#  'rikitea',
#  'malaya serdoba',
#  'samarai',
#  'kodiak',
#  'tasiilaq',
#  'delvine',
#  'bowen',
#  'dikson',
#  'ilulissat',
#  'hobart',
#  'barrow',
#  'mar del plata',
#  'vaini',
#  'olafsvik',
#  'camacupa',
#  'punta arenas',
#  'arlit',
#  'port hedland',
#  'rawson',
#  'port blair',
#  'laurel',
#  'krasnoselkup',
#  'puerto ayora',
#  'busselton',
#  'jakar',
#  'ostrovnoy',
#  'pevek',
#  'soanierana ivongo',
#  'ushuaia',
#  'wanlaweyn',
#  'ucluelet',
#  'kenai',
#  'coquimbo',
#  'ponta do sol',
#  'xai-xai',
#  'kapaa',
#  'matagami',
#  'san joaquin',
#  'pangkah',
#  'nicoya',
#  'hilo',
#  'magadan',
#  'umuahia',
#  'narsaq',
#  'upernavik',
#  'bageshwar',
#  'prince rupert',
#  'plainview',
#  'bredasdorp',
#  'chicama',
#  'saskylakh',
#  'carballo',
#  'flinders',
#  'rincon',
#  'saint-augustin',
#  'carbonia',
#  'we',
#  'safaqis',
#  'hermanus',
#  'bor',
#  'clyde river',
#  'sentyabrskiy',
#  'vestmannaeyjar',
#  'porbandar',
#  'stamsund',
#  'fairbanks',
#  'darovskoy',
#  'oksfjord',
#  'souillac',
#  'grand-santi',
#  'port moresby',
#  'povenets',
#  'am timan',
#  'manokwari',
#  'atuona',
#  'santa rosa',
#  'new norfolk',
#  'luanda',
#  'hithadhoo',
#  'rabo de peixe',
#  'beatrice',
#  'sorland',
#  'haibowan',
#  'rio gallegos',
#  'kahului',
#  'araci',
#  'tuatapere',
#  'nago',
#  'kupang',
#  'mys shmidta',
#  'bengkulu',
#  'bethel',
#  'patnagarh',
#  'lavrentiya',
#  'dandong',
#  'bambous virieux',
#  'santa cruz',
#  'klaksvik',
#  'tornio',
#  'sambava',
#  'tuktoyaktuk',
#  'korhogo',
#  'egvekinot',
#  'play cu',
#  'burnie',
#  'jamestown',
#  'rungata',
#  'reserva',
#  'kailua',
#  'ust-nera',
#  'palabuhanratu',
#  'agirish',
#  'port lincoln',
#  'roma',
#  'thompson',
#  'badou',
#  'coruripe',
#  'erenhot',
#  'lolua',
#  'sao miguel do araguaia',
#  'brae',
#  'ribeira grande',
#  'port-cartier',
#  'grand gaube',
#  'aklavik',
#  'safford',
#  'crab hill',
#  'porto novo',
#  'deputatskiy',
#  'portland',
#  'meulaboh',
#  'male',
#  'samusu',
#  'bontang',
#  'kaitangata',
#  'sitka',
#  'agua dulce',
#  'castro',
#  'puerto narino',
#  'khatanga',
#  'la palma',
#  'vanavara',
#  'teguise',
#  'gat',
#  'yarmouth',
#  'huarmey',
#  'korla',
#  'vysokogornyy',
#  'kushima',
#  'mandurah',
#  'half moon bay',
#  'marcona',
#  'komsomolskiy',
#  'hobyo',
#  'tekeli',
#  'perth',
#  'progreso',
#  'severodvinsk',
#  'road town',
#  'isangel',
#  'sao filipe',
#  'mega',
#  'charters towers',
#  'muros',
#  'novosheshminsk',
#  'fairmount',
#  'jerome',
#  'saint-philippe',
#  'coos bay',
#  'suntar',
#  'luderitz',
#  'soderhamn',
#  'tiznit',
#  'arucas',
#  'alakurtti',
#  'kandrian',
#  'sisimiut',
#  'cap malheureux',
#  'arraial do cabo',
#  'bilma',
#  'puerto santander',
#  'bandarbeyla',
#  'kpandu',
#  'vagur',
#  'te anau',
#  'karlskrona',
#  'nola',
#  'mana',
#  'saldanha',
#  'mount isa',
#  'sao manuel',
#  'tucuman',
#  'santa marta',
#  'carnarvon',
#  'provideniya',
#  'shimoda',
#  'hihifo',
#  'matara',
#  'nioki',
#  'avarua',
#  'kangaatsiaq',
#  'whyalla',
#  'huilong',
#  'kalmunai',
#  'tahe',
#  'speightstown',
#  'broken hill',
#  'manzil salim',
#  'pasighat',
#  'essex',
#  'kavieng',
#  'sayyan',
#  'tumannyy',
#  'belushya guba',
#  'esperance',
#  'fortuna',
#  'lata',
#  'oyama',
#  'zlate moravce',
#  'auki',
#  'tabuk',
#  'ilanskiy',
#  'new waterford',
#  'manggar',
#  'manyoni',
#  'kruisfontein',
#  'maraa',
#  'haines junction',
#  'novoye leushino',
#  'anloga',
#  'batemans bay',
#  'airai',
#  'bathsheba',
#  'gamba',
#  'vila franca do campo',
#  'chokurdakh',
#  'galiwinku',
#  'trelew',
#  'maneadero',
#  'datong',
#  'galveston',
#  'mayumba',
#  'yellowknife',
#  'rio grande',
#  'berlevag',
#  'rawannawi',
#  'vanimo',
#  'salalah',
#  'harper',
#  'zhicheng',
#  'san luis',
#  'talnakh',
#  'qinhuangdao',
#  'hofn',
#  'williams lake',
#  'mocuba',
#  'asau',
#  'erzin',
#  'tortoli',
#  'birjand',
#  'oriximina',
#  'havelock',
#  'labytnangi',
#  'san carlos de bariloche',
#  'faanui',
#  'cabo san lucas',
#  'turukhansk',
#  'niceville',
#  'mirnyy',
#  'jacareacanga',
#  'dindigul',
#  'margate',
#  'pangnirtung',
#  'mahebourg',
#  'sol-iletsk',
#  'anadyr',
#  'arroyo',
#  'ruatoria',
#  'jawhar',
#  'tongliao',
#  'statesboro',
#  'zemaiciu naumiestis',
#  'krasnogorsk',
#  'buique',
#  'caldas novas',
#  'oranjemund',
#  'marsh harbour',
#  'karla',
#  'holme',
#  'dunedin',
#  'cayenne',
#  'aykino',
#  'beloha',
#  'dayong',
#  'srednekolymsk',
#  'muravlenko',
#  'gerash',
#  'longyearbyen',
#  'katha',
#  'sioux lookout',
#  'nashville',
#  'jiroft',
#  'hefei',
#  'monywa',
#  'nome',
#  'babanusah',
#  'nizhniy odes',
#  'shushtar',
#  'havoysund',
#  'amahai',
#  'kalabo',
#  'nouadhibou',
#  'tsihombe',
#  'tiksi',
#  'herrin',
#  'zemio',
#  'beringovskiy',
#  'pacific grove',
#  'barentsburg',
#  'santa isabel do rio negro',
#  'yeppoon',
#  'constitucion',
#  'flin flon',
#  'karangampel',
#  'onega',
#  'mujiayingzi',
#  'aksu',
#  'laguna',
#  'nikki',
#  'maragogi',
#  'hemnesberget',
#  'waingapu',
#  'torbay',
#  'sarishabari',
#  'proletariy',
#  'belaya kholunitsa',
#  'harlingen',
#  'marfino',
#  'arkhangelsk',
#  'mecca',
#  'salme',
#  'tirumullaivasal',
#  'broome',
#  'ponta delgada',
#  'bodmin',
#  'cervo',
#  'tilichiki',
#  'dekar',
#  'dakar',
#  'den helder',
#  'cidreira',
#  'saleaula',
#  'kaoma',
#  'westpunt',
#  'aykhal',
#  'roald',
#  'moroto',
#  'zhangye',
#  'saint george',
#  'linares',
#  'ferrol',
#  'amqui',
#  'bethanien',
#  'adrar',
#  'haukipudas',
#  'grand river south east',
#  'jalu',
#  'ilka',
#  'andros town',
#  'rolim de moura',
#  'andenes',
#  'jinji',
#  'taltal',
#  'port maria',
#  'shingu',
#  'brownsville',
#  'katsuura',
#  'akhmim',
#  'kidal',
#  'baykit',
#  'goure',
#  'umzimvubu',
#  'itapirapua',
#  'imeni poliny osipenko',
#  'baker city',
#  'port augusta',
#  'aleksandrovskiy zavod',
#  'nemuro',
#  'ngukurr',
#  'yurimaguas',
#  'ahipara',
#  'mahibadhoo',
#  'namibe',
#  'bayir',
#  'leningradskiy',
#  'manacapuru',
#  'wagar',
#  'victor harbor',
#  'geilo',
#  'digby',
#  'garowe',
#  'acaponeta',
#  'kaputa',
#  'zaysan',
#  'baijiantan',
#  'maceio',
#  'tanout',
#  'mantua',
#  'socorro',
#  'whitianga',
#  'manuk mangkaw',
#  'pingliang',
#  'westport',
#  'ugoofaaru',
#  'nipawin',
#  'envira',
#  'avera',
#  'islamkot',
#  'khonuu',
#  'bereda',
#  'san patricio',
#  'opuwo',
#  'salekhard',
#  'amnat charoen',
#  'stabat',
#  'mandalgovi',
#  'pisco',
#  'acapulco',
#  'la paz',
#  'acajutla',
#  'aracati',
#  'port-gentil',
#  'lagoa',
#  'mersing',
#  'yulara',
#  'ouallam',
#  'chumikan',
#  'maniitsoq',
#  'moussoro',
#  'urcos',
#  'sur',
#  'severo-kurilsk',
#  'zhuhai',
#  'garbolovo',
#  'namatanai',
#  'ust-tsilma',
#  'cartagena del chaira',
#  'kjollefjord',
#  'kiama',
#  'behbahan',
#  'taoudenni',
#  'zachary',
#  'harer',
#  'viedma',
#  'alofi',
#  'lakeway',
#  'tete',
#  'bubaque',
#  'murgab',
#  'kodinsk',
#  'ainazi',
#  'talca',
#  'plon',
#  'bur gabo',
#  'nhulunbuy',
#  'kralendijk',
#  'juan lacaze',
#  'sibolga',
#  'buala',
#  'la garriga',
#  'wajir',
#  'talaya',
#  'vila do maio',
#  'pokhara',
#  'malakal',
#  'nizhneyansk',
#  'norman wells',
#  'aneho',
#  'verkhnevilyuysk',
#  'vostok',
#  'goba',
#  'lincoln',
#  'dondo',
#  'ketchikan',
#  'touros',
#  'sorong',
#  'ossora',
#  'gazanjyk',
#  'qasigiannguit',
#  'grand island',
#  'catuday',
#  'houma',
#  'kisangani',
#  'kurumkan',
#  'pemangkat',
#  'salym',
#  'noumea',
#  'arman',
#  'oskaloosa',
#  'dalbandin',
#  'kologriv',
#  'muli',
#  'severobaykalsk',
#  'hay river',
#  'amberley',
#  'port macquarie',
#  'barra patuca',
#  'gurgan',
#  'nantucket',
#  'khlung',
#  'mergui',
#  'hervey bay',
#  'kudahuvadhoo',
#  'nurota',
#  'barra do garcas',
#  'saratovskaya',
#  'burica',
#  'naze',
#  'megion',
#  'sao joao da barra',
#  'volax',
#  'poum',
#  'southbridge',
#  'verkhoyansk',
#  'homer',
#  'ndjole',
#  'sorvag',
#  'salinas',
#  'kirakira',
#  'caravelas',
#  'comodoro rivadavia',
#  'the valley',
#  'kendari',
#  'boa vista',
#  'coachella',
#  'barahan',
#  'hunza',
#  'mitsamiouli',
#  'vaitupu',
#  'yialos',
#  'slavutych',
#  'kamenica',
#  'tezu',
#  'kyra',
#  'mackay',
#  'codrington',
#  'cleethorpes',
#  'nabire',
#  'newport',
#  'mehamn',
#  'babu',
#  'quatre cocos',
#  'tabuleiro do norte',
#  'geraldton',
#  'zakamensk',
#  'tura',
#  'heihe',
#  'kifri',
#  'kankakee',
#  'vagay',
#  'ancud',
#  'cockburn town',
#  'geresk',
#  'vung tau',
#  'yumen',
#  'konosha',
#  'saint-pierre',
#  'tingi',
#  'phrai bung',
#  'ranavav',
#  'raudeberg',
#  'san cristobal',
#  'kislovodsk',
#  'vao',
#  'saint-francois',
#  'boende',
#  'neiafu',
#  'penzance',
#  'kwinana',
#  'letlhakane',
#  'joshimath',
#  'molaoi',
#  'ust-kamchatsk',
#  'hualmay',
#  'thurso',
#  'ariquemes',
#  'veraval',
#  'pundaguitan',
#  'podor',
#  'fort-shevchenko',
#  'sungaipenuh',
#  'jining',
#  'norwich',
#  'merrill',
#  'dera bugti',
#  'kropotkin',
#  'troitsko-pechorsk',
#  'liuhe',
#  'bentiu',
#  'nichinan',
#  'sinnamary',
#  'amga',
#  'khormuj',
#  'almansa',
#  'svetlogorsk',
#  'qaqortoq',
#  'meadow lake',
#  'makat',
#  'aquiraz',
#  'azul',
#  'kangavar',
#  'kholodnyy',
#  'dingle',
#  'yar-sale',
#  'susanville',
#  'ocean city',
#  'thayetmyo',
#  'buraydah',
#  'alyangula',
#  'ambatondrazaka',
#  'nizwa',
#  'tigzirt',
#  'alibag',
#  'petropavlovsk-kamchatskiy',
#  'lukovetskiy',
#  'ryotsu',
#  'mandera',
#  'college',
#  'starkville',
#  'hambantota',
#  'salon-de-provence',
#  'anuradhapura',
#  'beboto',
#  'hasaki',
#  'grindavik',
#  'peniche',
#  'balykshi',
#  'kamenskoye',
#  'batticaloa',
#  'mezen',
#  'knysna',
#  'simao',
#  'varkaus',
#  'zanjan',
#  'sao geraldo do araguaia',
#  'poronaysk',
#  'iskateley',
#  'saquena',
#  'kortkeros',
#  'tenenkou',
#  'shepetivka',
#  'longlac',
#  'batouri',
#  'gasa',
#  'mudanya',
#  'ajdabiya',
#  'chodavaram',
#  'asyut',
#  'luebo',
#  'mount hagen',
#  'kamenka',
#  'bure',
#  'nyurba',
#  'gweta',
#  'dubrovnik',
#  'zenzeli',
#  'hamilton',
#  'kottayam',
#  'lodwar',
#  'pinsk',
#  'iisalmi',
#  'alta floresta',
#  'alsozsolca',
#  'mapiri',
#  'necochea',
#  'uray',
#  'bang saphan',
#  'port hardy',
#  'rocha',
#  'alotau',
#  'north bend',
#  'maldonado',
#  'panji',
#  'fare',
#  'tiarei',
#  'mount clemens',
#  'ilinskiy',
#  'ankpa',
#  'kuche',
#  'shubarshi',
#  'santa lucia',
#  'davila',
#  'angoche',
#  'guane',
#  'zalantun',
#  'loa janan',
#  'galesong',
#  'cowansville',
#  'lokosovo',
#  'ahuimanu',
#  'doctor pedro p. pena',
#  'keskin',
#  'coahuayana',
#  'elizabeth city',
#  'itoman',
#  'domingos martins',
#  'bonthe',
#  'manaure',
#  'puerto del rosario',
#  'kutum',
#  'marawi',
#  'akyab',
#  'kismayo',
#  'zaragoza',
#  'moranbah',
#  'paradwip',
#  'lompoc',
#  'san jose',
#  'santa maria',
#  'uarini',
#  'honningsvag',
#  'yakima',
#  'villa carlos paz',
#  'agueda',
#  'rakaia',
#  'tateyama',
#  'kindu',
#  'villarrica',
#  'praya',
#  'san agustin',
#  'ler',
#  'abonnema',
#  'asfi',
#  'balkhash',
#  'kistelek',
#  'lulea',
#  'alice springs',
#  'mahon']

# %%
# Create waether data list
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through cities
for i, city in enumerate(cities):

    # Group cities for logging
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create URL
    city_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key + '&q=' + city.replace(" ","+")

    # Log the record, set and city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1

    # API request
    try:
        # Parse the JSON
        city_weather = requests.get(city_url).json()
        
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description']

        # Append the data into the list
        city_data.append({'City': city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})
    except:
        print('City not found. Skipping...')
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 1 | lorengau
# Processing Record 3 of Set 1 | eldikan
# City not found. Skipping...
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | east london
# Processing Record 6 of Set 1 | shenjiamen
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | iqaluit
# Processing Record 11 of Set 1 | hovd
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | kilcullen
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | goderich
# Processing Record 17 of Set 1 | chuy
# Processing Record 18 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 1 | nampula
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | vardo
# Processing Record 25 of Set 1 | polunochnoye
# Processing Record 26 of Set 1 | nanortalik
# Processing Record 27 of Set 1 | rundu
# Processing Record 28 of Set 1 | mount gambier
# Processing Record 29 of Set 1 | cherskiy
# Processing Record 30 of Set 1 | victoria
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | prince albert
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | malaya serdoba
# Processing Record 38 of Set 1 | samarai
# Processing Record 39 of Set 1 | kodiak
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | delvine
# Processing Record 42 of Set 1 | bowen
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | ilulissat
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | olafsvik
# Processing Record 50 of Set 1 | camacupa
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | arlit
# Processing Record 3 of Set 2 | port hedland
# Processing Record 4 of Set 2 | rawson
# Processing Record 5 of Set 2 | port blair
# Processing Record 6 of Set 2 | laurel
# Processing Record 7 of Set 2 | krasnoselkup
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | jakar
# Processing Record 11 of Set 2 | ostrovnoy
# Processing Record 12 of Set 2 | pevek
# Processing Record 13 of Set 2 | soanierana ivongo
# Processing Record 14 of Set 2 | ushuaia
# Processing Record 15 of Set 2 | wanlaweyn
# Processing Record 16 of Set 2 | ucluelet
# Processing Record 17 of Set 2 | kenai
# Processing Record 18 of Set 2 | coquimbo
# Processing Record 19 of Set 2 | ponta do sol
# Processing Record 20 of Set 2 | xai-xai
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | matagami
# Processing Record 23 of Set 2 | san joaquin
# Processing Record 24 of Set 2 | pangkah
# Processing Record 25 of Set 2 | nicoya
# Processing Record 26 of Set 2 | hilo
# Processing Record 27 of Set 2 | magadan
# Processing Record 28 of Set 2 | umuahia
# Processing Record 29 of Set 2 | narsaq
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | bageshwar
# Processing Record 32 of Set 2 | prince rupert
# Processing Record 33 of Set 2 | plainview
# Processing Record 34 of Set 2 | bredasdorp
# Processing Record 35 of Set 2 | chicama
# Processing Record 36 of Set 2 | saskylakh
# Processing Record 37 of Set 2 | carballo
# Processing Record 38 of Set 2 | flinders
# Processing Record 39 of Set 2 | rincon
# Processing Record 40 of Set 2 | saint-augustin
# Processing Record 41 of Set 2 | carbonia
# Processing Record 42 of Set 2 | we
# City not found. Skipping...
# Processing Record 43 of Set 2 | safaqis
# City not found. Skipping...
# Processing Record 44 of Set 2 | hermanus
# Processing Record 45 of Set 2 | bor
# Processing Record 46 of Set 2 | clyde river
# Processing Record 47 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 2 | vestmannaeyjar
# Processing Record 49 of Set 2 | porbandar
# Processing Record 50 of Set 2 | stamsund
# City not found. Skipping...
# Processing Record 1 of Set 3 | fairbanks
# Processing Record 2 of Set 3 | darovskoy
# Processing Record 3 of Set 3 | oksfjord
# Processing Record 4 of Set 3 | souillac
# Processing Record 5 of Set 3 | grand-santi
# Processing Record 6 of Set 3 | port moresby
# Processing Record 7 of Set 3 | povenets
# Processing Record 8 of Set 3 | am timan
# Processing Record 9 of Set 3 | manokwari
# Processing Record 10 of Set 3 | atuona
# Processing Record 11 of Set 3 | santa rosa
# Processing Record 12 of Set 3 | new norfolk
# Processing Record 13 of Set 3 | luanda
# Processing Record 14 of Set 3 | hithadhoo
# Processing Record 15 of Set 3 | rabo de peixe
# Processing Record 16 of Set 3 | beatrice
# Processing Record 17 of Set 3 | sorland
# Processing Record 18 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 3 | rio gallegos
# Processing Record 20 of Set 3 | kahului
# Processing Record 21 of Set 3 | araci
# Processing Record 22 of Set 3 | tuatapere
# Processing Record 23 of Set 3 | nago
# Processing Record 24 of Set 3 | kupang
# Processing Record 25 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 3 | bengkulu
# Processing Record 27 of Set 3 | bethel
# Processing Record 28 of Set 3 | patnagarh
# Processing Record 29 of Set 3 | lavrentiya
# Processing Record 30 of Set 3 | dandong
# Processing Record 31 of Set 3 | bambous virieux
# Processing Record 32 of Set 3 | santa cruz
# Processing Record 33 of Set 3 | klaksvik
# Processing Record 34 of Set 3 | tornio
# Processing Record 35 of Set 3 | sambava
# Processing Record 36 of Set 3 | tuktoyaktuk
# Processing Record 37 of Set 3 | korhogo
# Processing Record 38 of Set 3 | egvekinot
# Processing Record 39 of Set 3 | play cu
# City not found. Skipping...
# Processing Record 40 of Set 3 | burnie
# Processing Record 41 of Set 3 | jamestown
# Processing Record 42 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 3 | reserva
# Processing Record 44 of Set 3 | kailua
# Processing Record 45 of Set 3 | ust-nera
# Processing Record 46 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 3 | agirish
# Processing Record 48 of Set 3 | port lincoln
# Processing Record 49 of Set 3 | roma
# Processing Record 50 of Set 3 | thompson
# Processing Record 1 of Set 4 | badou
# Processing Record 2 of Set 4 | coruripe
# Processing Record 3 of Set 4 | erenhot
# Processing Record 4 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 4 | sao miguel do araguaia
# Processing Record 6 of Set 4 | brae
# Processing Record 7 of Set 4 | ribeira grande
# Processing Record 8 of Set 4 | port-cartier
# Processing Record 9 of Set 4 | grand gaube
# Processing Record 10 of Set 4 | aklavik
# Processing Record 11 of Set 4 | safford
# Processing Record 12 of Set 4 | crab hill
# City not found. Skipping...
# Processing Record 13 of Set 4 | porto novo
# Processing Record 14 of Set 4 | deputatskiy
# Processing Record 15 of Set 4 | portland
# Processing Record 16 of Set 4 | meulaboh
# Processing Record 17 of Set 4 | male
# Processing Record 18 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 4 | bontang
# Processing Record 20 of Set 4 | kaitangata
# Processing Record 21 of Set 4 | sitka
# Processing Record 22 of Set 4 | agua dulce
# Processing Record 23 of Set 4 | castro
# Processing Record 24 of Set 4 | puerto narino
# Processing Record 25 of Set 4 | khatanga
# Processing Record 26 of Set 4 | la palma
# Processing Record 27 of Set 4 | vanavara
# Processing Record 28 of Set 4 | teguise
# Processing Record 29 of Set 4 | gat
# Processing Record 30 of Set 4 | yarmouth
# Processing Record 31 of Set 4 | huarmey
# Processing Record 32 of Set 4 | korla
# Processing Record 33 of Set 4 | vysokogornyy
# Processing Record 34 of Set 4 | kushima
# Processing Record 35 of Set 4 | mandurah
# Processing Record 36 of Set 4 | half moon bay
# Processing Record 37 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 4 | komsomolskiy
# Processing Record 39 of Set 4 | hobyo
# Processing Record 40 of Set 4 | tekeli
# Processing Record 41 of Set 4 | perth
# Processing Record 42 of Set 4 | progreso
# Processing Record 43 of Set 4 | severodvinsk
# Processing Record 44 of Set 4 | road town
# Processing Record 45 of Set 4 | isangel
# Processing Record 46 of Set 4 | sao filipe
# Processing Record 47 of Set 4 | mega
# Processing Record 48 of Set 4 | charters towers
# Processing Record 49 of Set 4 | muros
# Processing Record 50 of Set 4 | novosheshminsk
# Processing Record 1 of Set 5 | fairmount
# Processing Record 2 of Set 5 | jerome
# Processing Record 3 of Set 5 | saint-philippe
# Processing Record 4 of Set 5 | coos bay
# Processing Record 5 of Set 5 | suntar
# Processing Record 6 of Set 5 | luderitz
# Processing Record 7 of Set 5 | soderhamn
# Processing Record 8 of Set 5 | tiznit
# Processing Record 9 of Set 5 | arucas
# Processing Record 10 of Set 5 | alakurtti
# Processing Record 11 of Set 5 | kandrian
# Processing Record 12 of Set 5 | sisimiut
# Processing Record 13 of Set 5 | cap malheureux
# Processing Record 14 of Set 5 | arraial do cabo
# Processing Record 15 of Set 5 | bilma
# Processing Record 16 of Set 5 | puerto santander
# Processing Record 17 of Set 5 | bandarbeyla
# Processing Record 18 of Set 5 | kpandu
# Processing Record 19 of Set 5 | vagur
# Processing Record 20 of Set 5 | te anau
# Processing Record 21 of Set 5 | karlskrona
# Processing Record 22 of Set 5 | nola
# Processing Record 23 of Set 5 | mana
# Processing Record 24 of Set 5 | saldanha
# Processing Record 25 of Set 5 | mount isa
# Processing Record 26 of Set 5 | sao manuel
# Processing Record 27 of Set 5 | tucuman
# Processing Record 28 of Set 5 | santa marta
# Processing Record 29 of Set 5 | carnarvon
# Processing Record 30 of Set 5 | provideniya
# Processing Record 31 of Set 5 | shimoda
# Processing Record 32 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 5 | matara
# Processing Record 34 of Set 5 | nioki
# Processing Record 35 of Set 5 | avarua
# Processing Record 36 of Set 5 | kangaatsiaq
# Processing Record 37 of Set 5 | whyalla
# Processing Record 38 of Set 5 | huilong
# Processing Record 39 of Set 5 | kalmunai
# Processing Record 40 of Set 5 | tahe
# Processing Record 41 of Set 5 | speightstown
# Processing Record 42 of Set 5 | broken hill
# Processing Record 43 of Set 5 | manzil salim
# Processing Record 44 of Set 5 | pasighat
# Processing Record 45 of Set 5 | essex
# Processing Record 46 of Set 5 | kavieng
# Processing Record 47 of Set 5 | sayyan
# Processing Record 48 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 5 | esperance
# Processing Record 1 of Set 6 | fortuna
# Processing Record 2 of Set 6 | lata
# Processing Record 3 of Set 6 | oyama
# Processing Record 4 of Set 6 | zlate moravce
# Processing Record 5 of Set 6 | auki
# Processing Record 6 of Set 6 | tabuk
# Processing Record 7 of Set 6 | ilanskiy
# Processing Record 8 of Set 6 | new waterford
# Processing Record 9 of Set 6 | manggar
# Processing Record 10 of Set 6 | manyoni
# Processing Record 11 of Set 6 | kruisfontein
# Processing Record 12 of Set 6 | maraa
# Processing Record 13 of Set 6 | haines junction
# Processing Record 14 of Set 6 | novoye leushino
# Processing Record 15 of Set 6 | anloga
# Processing Record 16 of Set 6 | batemans bay
# Processing Record 17 of Set 6 | airai
# Processing Record 18 of Set 6 | bathsheba
# Processing Record 19 of Set 6 | gamba
# Processing Record 20 of Set 6 | vila franca do campo
# Processing Record 21 of Set 6 | chokurdakh
# Processing Record 22 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 23 of Set 6 | trelew
# Processing Record 24 of Set 6 | maneadero
# Processing Record 25 of Set 6 | datong
# Processing Record 26 of Set 6 | galveston
# Processing Record 27 of Set 6 | mayumba
# Processing Record 28 of Set 6 | yellowknife
# Processing Record 29 of Set 6 | rio grande
# Processing Record 30 of Set 6 | berlevag
# Processing Record 31 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 6 | vanimo
# Processing Record 33 of Set 6 | salalah
# Processing Record 34 of Set 6 | harper
# Processing Record 35 of Set 6 | zhicheng
# Processing Record 36 of Set 6 | san luis
# Processing Record 37 of Set 6 | talnakh
# Processing Record 38 of Set 6 | qinhuangdao
# Processing Record 39 of Set 6 | hofn
# Processing Record 40 of Set 6 | williams lake
# Processing Record 41 of Set 6 | mocuba
# Processing Record 42 of Set 6 | asau
# Processing Record 43 of Set 6 | erzin
# Processing Record 44 of Set 6 | tortoli
# Processing Record 45 of Set 6 | birjand
# Processing Record 46 of Set 6 | oriximina
# Processing Record 47 of Set 6 | havelock
# Processing Record 48 of Set 6 | labytnangi
# Processing Record 49 of Set 6 | san carlos de bariloche
# Processing Record 50 of Set 6 | faanui
# Processing Record 1 of Set 7 | cabo san lucas
# Processing Record 2 of Set 7 | turukhansk
# Processing Record 3 of Set 7 | niceville
# Processing Record 4 of Set 7 | mirnyy
# Processing Record 5 of Set 7 | jacareacanga
# Processing Record 6 of Set 7 | dindigul
# Processing Record 7 of Set 7 | margate
# Processing Record 8 of Set 7 | pangnirtung
# Processing Record 9 of Set 7 | mahebourg
# Processing Record 10 of Set 7 | sol-iletsk
# Processing Record 11 of Set 7 | anadyr
# Processing Record 12 of Set 7 | arroyo
# Processing Record 13 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 14 of Set 7 | jawhar
# Processing Record 15 of Set 7 | tongliao
# Processing Record 16 of Set 7 | statesboro
# Processing Record 17 of Set 7 | zemaiciu naumiestis
# Processing Record 18 of Set 7 | krasnogorsk
# Processing Record 19 of Set 7 | buique
# Processing Record 20 of Set 7 | caldas novas
# Processing Record 21 of Set 7 | oranjemund
# Processing Record 22 of Set 7 | marsh harbour
# Processing Record 23 of Set 7 | karla
# Processing Record 24 of Set 7 | holme
# Processing Record 25 of Set 7 | dunedin
# Processing Record 26 of Set 7 | cayenne
# Processing Record 27 of Set 7 | aykino
# Processing Record 28 of Set 7 | beloha
# Processing Record 29 of Set 7 | dayong
# Processing Record 30 of Set 7 | srednekolymsk
# Processing Record 31 of Set 7 | muravlenko
# Processing Record 32 of Set 7 | gerash
# Processing Record 33 of Set 7 | longyearbyen
# Processing Record 34 of Set 7 | katha
# City not found. Skipping...
# Processing Record 35 of Set 7 | sioux lookout
# Processing Record 36 of Set 7 | nashville
# Processing Record 37 of Set 7 | jiroft
# City not found. Skipping...
# Processing Record 38 of Set 7 | hefei
# Processing Record 39 of Set 7 | monywa
# Processing Record 40 of Set 7 | nome
# Processing Record 41 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 42 of Set 7 | nizhniy odes
# Processing Record 43 of Set 7 | shushtar
# Processing Record 44 of Set 7 | havoysund
# Processing Record 45 of Set 7 | amahai
# Processing Record 46 of Set 7 | kalabo
# Processing Record 47 of Set 7 | nouadhibou
# Processing Record 48 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 7 | tiksi
# Processing Record 50 of Set 7 | herrin
# Processing Record 1 of Set 8 | zemio
# Processing Record 2 of Set 8 | beringovskiy
# Processing Record 3 of Set 8 | pacific grove
# Processing Record 4 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 8 | santa isabel do rio negro
# Processing Record 6 of Set 8 | yeppoon
# Processing Record 7 of Set 8 | constitucion
# Processing Record 8 of Set 8 | flin flon
# Processing Record 9 of Set 8 | karangampel
# Processing Record 10 of Set 8 | onega
# Processing Record 11 of Set 8 | mujiayingzi
# Processing Record 12 of Set 8 | aksu
# Processing Record 13 of Set 8 | laguna
# Processing Record 14 of Set 8 | nikki
# Processing Record 15 of Set 8 | maragogi
# Processing Record 16 of Set 8 | hemnesberget
# Processing Record 17 of Set 8 | waingapu
# Processing Record 18 of Set 8 | torbay
# Processing Record 19 of Set 8 | sarishabari
# Processing Record 20 of Set 8 | proletariy
# Processing Record 21 of Set 8 | belaya kholunitsa
# Processing Record 22 of Set 8 | harlingen
# Processing Record 23 of Set 8 | marfino
# Processing Record 24 of Set 8 | arkhangelsk
# Processing Record 25 of Set 8 | mecca
# Processing Record 26 of Set 8 | salme
# Processing Record 27 of Set 8 | tirumullaivasal
# Processing Record 28 of Set 8 | broome
# Processing Record 29 of Set 8 | ponta delgada
# Processing Record 30 of Set 8 | bodmin
# Processing Record 31 of Set 8 | cervo
# Processing Record 32 of Set 8 | tilichiki
# Processing Record 33 of Set 8 | dekar
# Processing Record 34 of Set 8 | dakar
# Processing Record 35 of Set 8 | den helder
# Processing Record 36 of Set 8 | cidreira
# Processing Record 37 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 8 | kaoma
# Processing Record 39 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 40 of Set 8 | aykhal
# Processing Record 41 of Set 8 | roald
# Processing Record 42 of Set 8 | moroto
# Processing Record 43 of Set 8 | zhangye
# Processing Record 44 of Set 8 | saint george
# Processing Record 45 of Set 8 | linares
# Processing Record 46 of Set 8 | ferrol
# Processing Record 47 of Set 8 | amqui
# Processing Record 48 of Set 8 | bethanien
# Processing Record 49 of Set 8 | adrar
# Processing Record 50 of Set 8 | haukipudas
# Processing Record 1 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 9 | jalu
# Processing Record 3 of Set 9 | ilka
# City not found. Skipping...
# Processing Record 4 of Set 9 | andros town
# Processing Record 5 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 6 of Set 9 | andenes
# Processing Record 7 of Set 9 | jinji
# Processing Record 8 of Set 9 | taltal
# Processing Record 9 of Set 9 | port maria
# Processing Record 10 of Set 9 | shingu
# Processing Record 11 of Set 9 | brownsville
# Processing Record 12 of Set 9 | katsuura
# Processing Record 13 of Set 9 | akhmim
# Processing Record 14 of Set 9 | kidal
# Processing Record 15 of Set 9 | baykit
# Processing Record 16 of Set 9 | goure
# Processing Record 17 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 9 | itapirapua
# Processing Record 19 of Set 9 | imeni poliny osipenko
# Processing Record 20 of Set 9 | baker city
# Processing Record 21 of Set 9 | port augusta
# Processing Record 22 of Set 9 | aleksandrovskiy zavod
# Processing Record 23 of Set 9 | nemuro
# Processing Record 24 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 9 | yurimaguas
# Processing Record 26 of Set 9 | ahipara
# Processing Record 27 of Set 9 | mahibadhoo
# Processing Record 28 of Set 9 | namibe
# Processing Record 29 of Set 9 | bayir
# Processing Record 30 of Set 9 | leningradskiy
# Processing Record 31 of Set 9 | manacapuru
# Processing Record 32 of Set 9 | wagar
# Processing Record 33 of Set 9 | victor harbor
# Processing Record 34 of Set 9 | geilo
# Processing Record 35 of Set 9 | digby
# Processing Record 36 of Set 9 | garowe
# Processing Record 37 of Set 9 | acaponeta
# Processing Record 38 of Set 9 | kaputa
# Processing Record 39 of Set 9 | zaysan
# Processing Record 40 of Set 9 | baijiantan
# Processing Record 41 of Set 9 | maceio
# Processing Record 42 of Set 9 | tanout
# Processing Record 43 of Set 9 | mantua
# Processing Record 44 of Set 9 | socorro
# Processing Record 45 of Set 9 | whitianga
# Processing Record 46 of Set 9 | manuk mangkaw
# Processing Record 47 of Set 9 | pingliang
# Processing Record 48 of Set 9 | westport
# Processing Record 49 of Set 9 | ugoofaaru
# Processing Record 50 of Set 9 | nipawin
# Processing Record 1 of Set 10 | envira
# Processing Record 2 of Set 10 | avera
# Processing Record 3 of Set 10 | islamkot
# Processing Record 4 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 5 of Set 10 | bereda
# Processing Record 6 of Set 10 | san patricio
# Processing Record 7 of Set 10 | opuwo
# Processing Record 8 of Set 10 | salekhard
# Processing Record 9 of Set 10 | amnat charoen
# Processing Record 10 of Set 10 | stabat
# Processing Record 11 of Set 10 | mandalgovi
# Processing Record 12 of Set 10 | pisco
# Processing Record 13 of Set 10 | acapulco
# Processing Record 14 of Set 10 | la paz
# Processing Record 15 of Set 10 | acajutla
# Processing Record 16 of Set 10 | aracati
# Processing Record 17 of Set 10 | port-gentil
# Processing Record 18 of Set 10 | lagoa
# Processing Record 19 of Set 10 | mersing
# Processing Record 20 of Set 10 | yulara
# Processing Record 21 of Set 10 | ouallam
# Processing Record 22 of Set 10 | chumikan
# Processing Record 23 of Set 10 | maniitsoq
# Processing Record 24 of Set 10 | moussoro
# Processing Record 25 of Set 10 | urcos
# Processing Record 26 of Set 10 | sur
# Processing Record 27 of Set 10 | severo-kurilsk
# Processing Record 28 of Set 10 | zhuhai
# Processing Record 29 of Set 10 | garbolovo
# Processing Record 30 of Set 10 | namatanai
# Processing Record 31 of Set 10 | ust-tsilma
# Processing Record 32 of Set 10 | cartagena del chaira
# Processing Record 33 of Set 10 | kjollefjord
# Processing Record 34 of Set 10 | kiama
# Processing Record 35 of Set 10 | behbahan
# Processing Record 36 of Set 10 | taoudenni
# Processing Record 37 of Set 10 | zachary
# Processing Record 38 of Set 10 | harer
# Processing Record 39 of Set 10 | viedma
# Processing Record 40 of Set 10 | alofi
# Processing Record 41 of Set 10 | lakeway
# Processing Record 42 of Set 10 | tete
# Processing Record 43 of Set 10 | bubaque
# Processing Record 44 of Set 10 | murgab
# Processing Record 45 of Set 10 | kodinsk
# Processing Record 46 of Set 10 | ainazi
# Processing Record 47 of Set 10 | talca
# Processing Record 48 of Set 10 | plon
# Processing Record 49 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 50 of Set 10 | nhulunbuy
# Processing Record 1 of Set 11 | kralendijk
# Processing Record 2 of Set 11 | juan lacaze
# Processing Record 3 of Set 11 | sibolga
# Processing Record 4 of Set 11 | buala
# Processing Record 5 of Set 11 | la garriga
# Processing Record 6 of Set 11 | wajir
# Processing Record 7 of Set 11 | talaya
# Processing Record 8 of Set 11 | vila do maio
# Processing Record 9 of Set 11 | pokhara
# Processing Record 10 of Set 11 | malakal
# Processing Record 11 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 11 | norman wells
# Processing Record 13 of Set 11 | aneho
# Processing Record 14 of Set 11 | verkhnevilyuysk
# Processing Record 15 of Set 11 | vostok
# Processing Record 16 of Set 11 | goba
# Processing Record 17 of Set 11 | lincoln
# Processing Record 18 of Set 11 | dondo
# Processing Record 19 of Set 11 | ketchikan
# Processing Record 20 of Set 11 | touros
# Processing Record 21 of Set 11 | sorong
# Processing Record 22 of Set 11 | ossora
# Processing Record 23 of Set 11 | gazanjyk
# Processing Record 24 of Set 11 | qasigiannguit
# Processing Record 25 of Set 11 | grand island
# Processing Record 26 of Set 11 | catuday
# Processing Record 27 of Set 11 | houma
# Processing Record 28 of Set 11 | kisangani
# Processing Record 29 of Set 11 | kurumkan
# Processing Record 30 of Set 11 | pemangkat
# Processing Record 31 of Set 11 | salym
# Processing Record 32 of Set 11 | noumea
# Processing Record 33 of Set 11 | arman
# Processing Record 34 of Set 11 | oskaloosa
# Processing Record 35 of Set 11 | dalbandin
# Processing Record 36 of Set 11 | kologriv
# Processing Record 37 of Set 11 | muli
# Processing Record 38 of Set 11 | severobaykalsk
# Processing Record 39 of Set 11 | hay river
# Processing Record 40 of Set 11 | amberley
# Processing Record 41 of Set 11 | port macquarie
# Processing Record 42 of Set 11 | barra patuca
# Processing Record 43 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 44 of Set 11 | nantucket
# Processing Record 45 of Set 11 | khlung
# Processing Record 46 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 47 of Set 11 | hervey bay
# Processing Record 48 of Set 11 | kudahuvadhoo
# Processing Record 49 of Set 11 | nurota
# Processing Record 50 of Set 11 | barra do garcas
# Processing Record 1 of Set 12 | saratovskaya
# Processing Record 2 of Set 12 | burica
# City not found. Skipping...
# Processing Record 3 of Set 12 | naze
# Processing Record 4 of Set 12 | megion
# Processing Record 5 of Set 12 | sao joao da barra
# Processing Record 6 of Set 12 | volax
# Processing Record 7 of Set 12 | poum
# Processing Record 8 of Set 12 | southbridge
# Processing Record 9 of Set 12 | verkhoyansk
# Processing Record 10 of Set 12 | homer
# Processing Record 11 of Set 12 | ndjole
# Processing Record 12 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 12 | salinas
# Processing Record 14 of Set 12 | kirakira
# Processing Record 15 of Set 12 | caravelas
# Processing Record 16 of Set 12 | comodoro rivadavia
# Processing Record 17 of Set 12 | the valley
# Processing Record 18 of Set 12 | kendari
# Processing Record 19 of Set 12 | boa vista
# Processing Record 20 of Set 12 | coachella
# Processing Record 21 of Set 12 | barahan
# Processing Record 22 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 23 of Set 12 | mitsamiouli
# Processing Record 24 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 12 | yialos
# City not found. Skipping...
# Processing Record 26 of Set 12 | slavutych
# Processing Record 27 of Set 12 | kamenica
# Processing Record 28 of Set 12 | tezu
# Processing Record 29 of Set 12 | kyra
# Processing Record 30 of Set 12 | mackay
# Processing Record 31 of Set 12 | codrington
# Processing Record 32 of Set 12 | cleethorpes
# Processing Record 33 of Set 12 | nabire
# Processing Record 34 of Set 12 | newport
# Processing Record 35 of Set 12 | mehamn
# Processing Record 36 of Set 12 | babu
# Processing Record 37 of Set 12 | quatre cocos
# Processing Record 38 of Set 12 | tabuleiro do norte
# Processing Record 39 of Set 12 | geraldton
# Processing Record 40 of Set 12 | zakamensk
# Processing Record 41 of Set 12 | tura
# Processing Record 42 of Set 12 | heihe
# Processing Record 43 of Set 12 | kifri
# Processing Record 44 of Set 12 | kankakee
# Processing Record 45 of Set 12 | vagay
# Processing Record 46 of Set 12 | ancud
# Processing Record 47 of Set 12 | cockburn town
# Processing Record 48 of Set 12 | geresk
# City not found. Skipping...
# Processing Record 49 of Set 12 | vung tau
# Processing Record 50 of Set 12 | yumen
# Processing Record 1 of Set 13 | konosha
# Processing Record 2 of Set 13 | saint-pierre
# Processing Record 3 of Set 13 | tingi
# Processing Record 4 of Set 13 | phrai bung
# City not found. Skipping...
# Processing Record 5 of Set 13 | ranavav
# Processing Record 6 of Set 13 | raudeberg
# Processing Record 7 of Set 13 | san cristobal
# Processing Record 8 of Set 13 | kislovodsk
# Processing Record 9 of Set 13 | vao
# Processing Record 10 of Set 13 | saint-francois
# Processing Record 11 of Set 13 | boende
# Processing Record 12 of Set 13 | neiafu
# Processing Record 13 of Set 13 | penzance
# Processing Record 14 of Set 13 | kwinana
# Processing Record 15 of Set 13 | letlhakane
# Processing Record 16 of Set 13 | joshimath
# Processing Record 17 of Set 13 | molaoi
# Processing Record 18 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 19 of Set 13 | hualmay
# Processing Record 20 of Set 13 | thurso
# Processing Record 21 of Set 13 | ariquemes
# Processing Record 22 of Set 13 | veraval
# Processing Record 23 of Set 13 | pundaguitan
# Processing Record 24 of Set 13 | podor
# Processing Record 25 of Set 13 | fort-shevchenko
# Processing Record 26 of Set 13 | sungaipenuh
# Processing Record 27 of Set 13 | jining
# Processing Record 28 of Set 13 | norwich
# Processing Record 29 of Set 13 | merrill
# Processing Record 30 of Set 13 | dera bugti
# Processing Record 31 of Set 13 | kropotkin
# Processing Record 32 of Set 13 | troitsko-pechorsk
# Processing Record 33 of Set 13 | liuhe
# Processing Record 34 of Set 13 | bentiu
# Processing Record 35 of Set 13 | nichinan
# Processing Record 36 of Set 13 | sinnamary
# Processing Record 37 of Set 13 | amga
# Processing Record 38 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 39 of Set 13 | almansa
# Processing Record 40 of Set 13 | svetlogorsk
# Processing Record 41 of Set 13 | qaqortoq
# Processing Record 42 of Set 13 | meadow lake
# Processing Record 43 of Set 13 | makat
# Processing Record 44 of Set 13 | aquiraz
# Processing Record 45 of Set 13 | azul
# Processing Record 46 of Set 13 | kangavar
# Processing Record 47 of Set 13 | kholodnyy
# Processing Record 48 of Set 13 | dingle
# Processing Record 49 of Set 13 | yar-sale
# Processing Record 50 of Set 13 | susanville
# Processing Record 1 of Set 14 | ocean city
# Processing Record 2 of Set 14 | thayetmyo
# Processing Record 3 of Set 14 | buraydah
# Processing Record 4 of Set 14 | alyangula
# Processing Record 5 of Set 14 | ambatondrazaka
# Processing Record 6 of Set 14 | nizwa
# Processing Record 7 of Set 14 | tigzirt
# Processing Record 8 of Set 14 | alibag
# Processing Record 9 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 14 | lukovetskiy
# Processing Record 11 of Set 14 | ryotsu
# Processing Record 12 of Set 14 | mandera
# Processing Record 13 of Set 14 | college
# Processing Record 14 of Set 14 | starkville
# Processing Record 15 of Set 14 | hambantota
# Processing Record 16 of Set 14 | salon-de-provence
# Processing Record 17 of Set 14 | anuradhapura
# Processing Record 18 of Set 14 | beboto
# Processing Record 19 of Set 14 | hasaki
# Processing Record 20 of Set 14 | grindavik
# Processing Record 21 of Set 14 | peniche
# Processing Record 22 of Set 14 | balykshi
# Processing Record 23 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 14 | batticaloa
# Processing Record 25 of Set 14 | mezen
# Processing Record 26 of Set 14 | knysna
# Processing Record 27 of Set 14 | simao
# Processing Record 28 of Set 14 | varkaus
# Processing Record 29 of Set 14 | zanjan
# Processing Record 30 of Set 14 | sao geraldo do araguaia
# Processing Record 31 of Set 14 | poronaysk
# Processing Record 32 of Set 14 | iskateley
# Processing Record 33 of Set 14 | saquena
# Processing Record 34 of Set 14 | kortkeros
# Processing Record 35 of Set 14 | tenenkou
# Processing Record 36 of Set 14 | shepetivka
# Processing Record 37 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 38 of Set 14 | batouri
# Processing Record 39 of Set 14 | gasa
# Processing Record 40 of Set 14 | mudanya
# Processing Record 41 of Set 14 | ajdabiya
# Processing Record 42 of Set 14 | chodavaram
# Processing Record 43 of Set 14 | asyut
# Processing Record 44 of Set 14 | luebo
# Processing Record 45 of Set 14 | mount hagen
# Processing Record 46 of Set 14 | kamenka
# Processing Record 47 of Set 14 | bure
# Processing Record 48 of Set 14 | nyurba
# Processing Record 49 of Set 14 | gweta
# Processing Record 50 of Set 14 | dubrovnik
# Processing Record 1 of Set 15 | zenzeli
# Processing Record 2 of Set 15 | hamilton
# Processing Record 3 of Set 15 | kottayam
# Processing Record 4 of Set 15 | lodwar
# Processing Record 5 of Set 15 | pinsk
# Processing Record 6 of Set 15 | iisalmi
# Processing Record 7 of Set 15 | alta floresta
# Processing Record 8 of Set 15 | alsozsolca
# Processing Record 9 of Set 15 | mapiri
# Processing Record 10 of Set 15 | necochea
# Processing Record 11 of Set 15 | uray
# Processing Record 12 of Set 15 | bang saphan
# Processing Record 13 of Set 15 | port hardy
# Processing Record 14 of Set 15 | rocha
# Processing Record 15 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 16 of Set 15 | north bend
# Processing Record 17 of Set 15 | maldonado
# Processing Record 18 of Set 15 | panji
# Processing Record 19 of Set 15 | fare
# Processing Record 20 of Set 15 | tiarei
# Processing Record 21 of Set 15 | mount clemens
# Processing Record 22 of Set 15 | ilinskiy
# Processing Record 23 of Set 15 | ankpa
# Processing Record 24 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 15 | shubarshi
# Processing Record 26 of Set 15 | santa lucia
# Processing Record 27 of Set 15 | davila
# Processing Record 28 of Set 15 | angoche
# Processing Record 29 of Set 15 | guane
# Processing Record 30 of Set 15 | zalantun
# Processing Record 31 of Set 15 | loa janan
# Processing Record 32 of Set 15 | galesong
# Processing Record 33 of Set 15 | cowansville
# Processing Record 34 of Set 15 | lokosovo
# Processing Record 35 of Set 15 | ahuimanu
# Processing Record 36 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 37 of Set 15 | keskin
# Processing Record 38 of Set 15 | coahuayana
# Processing Record 39 of Set 15 | elizabeth city
# Processing Record 40 of Set 15 | itoman
# Processing Record 41 of Set 15 | domingos martins
# Processing Record 42 of Set 15 | bonthe
# Processing Record 43 of Set 15 | manaure
# Processing Record 44 of Set 15 | puerto del rosario
# Processing Record 45 of Set 15 | kutum
# Processing Record 46 of Set 15 | marawi
# Processing Record 47 of Set 15 | akyab
# Processing Record 48 of Set 15 | kismayo
# Processing Record 49 of Set 15 | zaragoza
# Processing Record 50 of Set 15 | moranbah
# Processing Record 1 of Set 16 | paradwip
# City not found. Skipping...
# Processing Record 2 of Set 16 | lompoc
# Processing Record 3 of Set 16 | san jose
# Processing Record 4 of Set 16 | santa maria
# Processing Record 5 of Set 16 | uarini
# Processing Record 6 of Set 16 | honningsvag
# Processing Record 7 of Set 16 | yakima
# Processing Record 8 of Set 16 | villa carlos paz
# Processing Record 9 of Set 16 | agueda
# Processing Record 10 of Set 16 | rakaia
# Processing Record 11 of Set 16 | tateyama
# Processing Record 12 of Set 16 | kindu
# Processing Record 13 of Set 16 | villarrica
# Processing Record 14 of Set 16 | praya
# Processing Record 15 of Set 16 | san agustin
# Processing Record 16 of Set 16 | ler
# Processing Record 17 of Set 16 | abonnema
# Processing Record 18 of Set 16 | asfi
# Processing Record 19 of Set 16 | balkhash
# Processing Record 20 of Set 16 | kistelek
# Processing Record 21 of Set 16 | lulea
# Processing Record 22 of Set 16 | alice springs
# Processing Record 23 of Set 16 | mahon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
new_column = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
city_data_df = city_data_df[new_column]
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Lorengau      PG  -2.0226  147.2712     81.70        81         100
# 1      Port Alfred      ZA -33.5906   26.8910     60.30        81          93
# 2      East London      ZA -33.0153   27.9116     63.19        77          72
# 3       Shenjiamen      CN  29.9576  122.2980     69.08        94         100
# 4       Nikolskoye      RU  59.7035   30.7861     52.39        98          84
# ..             ...     ...      ...       ...       ...       ...         ...
# 710       Balkhash      KZ  46.8440   74.9804     68.76        46          27
# 711       Kistelek      HU  46.4725   19.9797     60.08        72         100
# 712          Lulea      SE  65.5842   22.1547     42.87        65          48
# 713  Alice Springs      AU -23.7000  133.8833     42.35        65          92
# 714          Mahon      ES  39.8885    4.2658     61.36        88           0
#
#      Wind Speed Current Description
# 0          6.35     overcast clouds
# 1         11.12     overcast clouds
# 2         11.90       broken clouds
# 3         14.14     overcast clouds
# 4          6.46       broken clouds
# ..          ...                 ...
# 710       30.13    scattered clouds
# 711       11.45     overcast clouds
# 712        2.30    scattered clouds
# 713        9.95     overcast clouds
# 714        4.61           clear sky
#
# [715 rows x 9 columns]

# %%
# Export DataFrame to CSV file
city_data_df.to_csv('weather_database/weatherpy_database.csv', index_label='City_ID')
